# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline 
#plt.show() yazmamak için

# %%
age = [10,25,30,42,55,67,79,85,93]
weight = [70,50,88,66,81,78,98,100,62]

# %%
numpyAge = np.array(age)
numpyWeight = np.array(weight)

# %%
plt.plot(numpyAge,numpyWeight,"g") #g rengin ne olacağını belirtir
plt.xlabel("Age")
plt.ylabel("Weight")
plt.title("Age/Weight")
plt.show()

# %%
numpyArray = np.linspace(0,10,20)
numpyArray
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyArray2 = numpyArray ** 3
numpyArray2
# Out:
# array([0.00000000e+00, 1.45793847e-01, 1.16635078e+00, 3.93643388e+00,
#        9.33080624e+00, 1.82242309e+01, 3.14914711e+01, 5.00072897e+01,
#        7.46464499e+01, 1.06283715e+02, 1.45793847e+02, 1.94051611e+02,
#        2.51931768e+02, 3.20309083e+02, 4.00058318e+02, 4.92054235e+02,
#        5.97171599e+02, 7.16285173e+02, 8.50269719e+02, 1.00000000e+03])

# %%
plt.plot(numpyArray,numpyArray2,"g*-")

# %%
plt.subplot(1,2,1)
plt.plot(numpyArray,numpyArray2,"r*-")
plt.subplot(1,2,2)
plt.plot(numpyArray2,numpyArray,"g--")

# %%
newFigure = plt.figure()
figureAxes = newFigure.add_axes([0.1,0.1,0.9,0.9])
# add_axes(-,-, plotWidth, plotHeight)
figureAxes.plot(numpyArray,numpyArray2,"g")
figureAxes.set_xlabel("Age")
figureAxes.set_ylabel("Weight")
figureAxes.set_title("Age/Weight")
# Out:
# Text(0.5, 1.0, 'Age/Weight')

# %%
figure2 = plt.figure()

eksen1 = figure2.add_axes([0.1,0.1,0.9,0.9])
eksen2 = figure2.add_axes([0.2,0.6,0.3,0.3])

eksen1.plot(numpyArray,numpyArray2,"g")
eksen1.set_xlabel("x ekseni")
eksen1.set_ylabel("y ekseni")
eksen1.set_title("Ana Grafik")

eksen2.plot(numpyArray2,numpyArray,"b")
eksen2.set_xlabel("x ekseni")
eksen2.set_ylabel("y ekseni")
eksen2.set_title("Sub Grafik")
# Out:
# Text(0.5, 1.0, 'Sub Grafik')

# %%
(figure3, eksen3) = plt.subplots(nrows=1, ncols=2)
type(eksen3) #numpy.ndarray

for eksenler in eksen3:
    eksenler.plot(numpyArray,numpyArray2,"g")
    
plt.tight_layout() # plotları birbirinden ayıracaktır

# %%
newFigure = plt.figure()

eksen4 = newFigure.add_axes([0.1,0.1,0.9,0.9])

eksen4.plot(numpyArray, numpyArray ** 2, label = "numpyArray ** 2")
eksen4.plot(numpyArray, numpyArray ** 3, label = "numpyArray ** 3")
eksen4.plot(numpyArray, numpyArray ** 3.1, label = "numpyArray ** 4")
eksen4.legend(loc=0) #loc legendin yerini değiştiriyor

# %%
#newFigure.savefig("denemeFigure", dpi = 800)

# %%
(figure4, eksen5) = plt.subplots()
eksen5.plot(numpyArray,numpyArray2,
            color = "#f97a93",
            alpha = 0.5,
            linewidth = 4,
            linestyle = "--",
            marker = "o",
            markersize = 9,
            markerfacecolor = "black")

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(numpyArray,numpyArray2)

# %% [markdown]
# ## Histogram

# %%
numpyArray3 = np.random.randint(0,100,50)
numpyArray3
# Out:
# array([64, 43, 13, 41,  4, 29,  3,  1, 68, 19, 62,  8, 35, 48, 26, 61, 30,
#        69, 66, 80, 37, 82,  8, 53, 31, 37, 71, 43, 42, 33, 73,  1, 37, 52,
#        92, 88, 67, 48, 62, 67, 51, 49, 79, 42,  4, 14, 89, 68, 48, 41])

# %%
plt.hist(numpyArray3)
# Out:
# (array([7., 3., 1., 8., 6., 7., 4., 8., 3., 3.]),
#  array([ 1. , 10.1, 19.2, 28.3, 37.4, 46.5, 55.6, 64.7, 73.8, 82.9, 92. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## BoxPlot

# %%
plt.boxplot(numpyArray3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24e9e52b160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24e9e52b880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24e9e42dd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x24e9e52bfa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24e9e536370>],
#  'means': []}
